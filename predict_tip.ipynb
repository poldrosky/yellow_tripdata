# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from pycaret.classification import *
import mlflow
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 500)
import numpy as np
import xgboost

# %%
dataset = pd.read_parquet('processed_data.parquet')

# %%
dataset.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  improvement_surcharge  total_amount  congestion_surcharge  airport_fee  pickup_hour  dropoff_hour  pickup_day  dropoff_day pickup_date dropoff_date pickup_drop_of  median_trip_distance  long_trip
# 0         1  2020-03-01 00:31:13   2020-03-01 01:01:42              1.0           4.70         1.0                  N            88           255             1         22.0    3.0      0.5        2.00           0.0                    0.3         27.80                   2.5          0.0            0             1           1            1  2020-03-01   2020-03-01         88_255                   4.8          0
# 1         2  2020-03-01 01:06:21   2020-03-01 01:33:20              3.0           6.51         1.0                  N            88           255             1         23.5    0.5      0.5        0.00           0.0                    0.3         27.30                   2.5          0.0            1             1           1            1  2020-03-01   2020-03-01         88_255                   4.8          0
# 2         2  2020-03-01 19:07:20   2020-03-01 19:26:55              1.0           5.89         1.0                  N            88           255             1         19.5    0.0      0.5        4.56           0.0                    0.3         27.36                   2.5          0.0           19            19           1            1  2020-03-01   2020-03-01         88_255                   4.8          0
# 3         1  2020-03-02 15:33:53   2020-03-02 16:14:23              2.0           7.30         1.0                  N            88           255             1         31.5    2.5      0.5        8.65           0.0                    0.3         43.45                   2.5          0.0           15            16           2            2  2020-03-02   2020-03-02         88_255                   4.8          0
# 4         2  2020-03-02 19:47:15   2020-03-02 20:07:43              5.0           4.81         1.0                  N            88           255             1         18.0    1.0      0.5        4.46           0.0                    0.3         26.76                   2.5          0.0           19            20           2            2  2020-03-02   2020-03-02         88_255                   4.8          0

# %% [markdown]
# ## Filtered payment_type == 1

# %%
dataset = dataset[dataset.payment_type == 1].reset_index(drop=True)

# %%
dataset['tip'] = dataset['tip_amount'].map(lambda x: 1 if x>0 else 0)

# %%
x_columns = [
    'passenger_count', 'PULocationID', 'DOLocationID',
    'congestion_surcharge', 'pickup_day', 'pickup_hour', 'fare_amount', 'extra', 'mta_tax', 'tolls_amount', 'airport_fee',   'tip']

# %%
data = dataset[x_columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(data, data['tip'],
                                                    stratify=data['tip'], 
                                                    test_size=0.15, random_state=42)

# %%
X_train['tip'] = y_train
X_test['tip'] = y_test

# %%
X_train = X_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)

# %%
X_train.shape
# Out:
# (14655215, 12)

# %%
X_test.shape
# Out:
# (2586215, 12)

# %%
X_train['tip'].value_counts()
# Out:
# 1    14190870
# 0      464345
# Name: tip, dtype: int64

# %%
X_train.shape
# Out:
# (14655215, 12)

# %%
X_train_sample = pd.concat([
    X_train[X_train.tip == 0], 
    X_train[X_train.tip == 1].sample(2000000),
])

# %%
X_train_sample.shape
# Out:
# (2464345, 12)

# %%
clf = setup(
    X_train_sample,
    target='tip',
    log_experiment = True,
    experiment_name = 'yellow_taxis_tip',
    silent=True)
# Out:
# <style  type="text/css" >
# #T_0ed24_row19_col1,#T_0ed24_row44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_0ed24_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0ed24_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0ed24_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_0ed24_row0_col1" class="data row0 col1" >6830</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed24_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_0ed24_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_0ed24_row1_col1" class="data row1 col1" >tip</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed24_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_0ed24_row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_0ed24_row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed24_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_0ed24_row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_0ed24_row3_col1" class="data row3 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed24_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_0ed24_row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_0ed24_row4_col1" class="data row4 col1" >(2464345, 12)</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed24_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_0ed24_row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_0ed24_row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed24_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_0ed24_row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_0ed24_row6_col1" class="data row6 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed24_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_0ed24_row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_0ed24_row7_col1" class="data row7 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed24_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_0ed24_row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_0ed24_row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed24_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_0ed24_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_0ed24_row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed24_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_0ed24_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_0ed24_row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed24_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_0ed24_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_0ed24_row11_col1" class="data row11 col1" >(1725041, 11)</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed24_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_0ed24_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_0ed24_row12_col1" class="data row12 col1" >(739304, 11)</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed24_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_0ed24_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_0ed24_row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed24_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_0ed24_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_0ed24_row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed24_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_0ed24_row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_0ed24_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed24_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_0ed24_row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_0ed24_row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed24_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_0ed24_row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_0ed24_row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed24_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_0ed24_row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_0ed24_row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed24_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_0ed24_row19_col0" class="data row19 col0" >Log Experiment</td>
#                         <td id="T_0ed24_row19_col1" class="data row19 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed24_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_0ed24_row20_col0" class="data row20 col0" >Experiment Name</td>
#                         <td id="T_0ed24_row20_col1" class="data row20 col1" >yellow_taxis_tip</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed24_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_0ed24_row21_col0" class="data row21 col0" >USI</td>
#                         <td id="T_0ed24_row21_col1" class="data row21 col1" >2646</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed24_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_0ed24_row22_col0" class="data row22 col0" >Imputation Type</td>
#                         <td id="T_0ed24_row22_col1" class="data row22 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed24_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_0ed24_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_0ed24_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_0ed24_level0_row24" class="row_headin

# %%
add_metric('prauc', 'PR AUC', metrics.average_precision_score, greater_is_better = True)
# Out:
# Name                                                            PR AUC
# Display Name                                                    PR AUC
# Score Function       <function average_precision_score at 0x7fe6dca...
# Scorer                            make_scorer(average_precision_score)
# Target                                                            pred
# Args                                                                {}
# Greater is Better                                                 True
# Multiclass                                                        True
# Custom                                                            True
# Name: prauc, dtype: object

# %%
best_models = compare_models(['lightgbm'])
# Out:
# <style  type="text/css" >
#     #T_6f9fb_ th {
#           text-align: left;
#     }#T_6f9fb_row0_col0{
#             text-align:  left;
#             text-align:  left;
#         }#T_6f9fb_row0_col1,#T_6f9fb_row0_col2,#T_6f9fb_row0_col3,#T_6f9fb_row0_col4,#T_6f9fb_row0_col5,#T_6f9fb_row0_col6,#T_6f9fb_row0_col7,#T_6f9fb_row0_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_6f9fb_row0_col9{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_6f9fb_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >PR AUC</th>        <th class="col_heading level0 col9" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6f9fb_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#                         <td id="T_6f9fb_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_6f9fb_row0_col1" class="data row0 col1" >0.8268</td>
#                         <td id="T_6f9fb_row0_col2" class="data row0 col2" >0.7054</td>
#                         <td id="T_6f9fb_row0_col3" class="data row0 col3" >0.9819</td>
#                         <td id="T_6f9fb_row0_col4" class="data row0 col4" >0.8341</td>
#                         <td id="T_6f9fb_row0_col5" class="data row0 col5" >0.9020</td>
#                         <td id="T_6f9fb_row0_col6" class="data row0 col6" >0.2003</td>
#                         <td id="T_6f9fb_row0_col7" class="data row0 col7" >0.2679</td>
#                         <td id="T_6f9fb_row0_col8" class="data row0 col8" >0.8337</td>
#                         <td id="T_6f9fb_row0_col9" class="data row0 col9" >6.5310</td>
#             </tr>
#     </tbody></table>

# %%
lightgbm_model = create_model('lightgbm',fold=10)
tuned_lightgbm = tune_model(lightgbm_model, optimize = 'prauc',fold=10)
# Out:
# <style  type="text/css" >
# #T_4f1e0_row10_col0,#T_4f1e0_row10_col1,#T_4f1e0_row10_col2,#T_4f1e0_row10_col3,#T_4f1e0_row10_col4,#T_4f1e0_row10_col5,#T_4f1e0_row10_col6,#T_4f1e0_row10_col7{
#             background:  yellow;
#         }</style><table id="T_4f1e0_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>        <th class="col_heading level0 col7" >PR AUC</th>    </tr>    <tr>        <th class="index_name level0" >Fold</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4f1e0_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4f1e0_row0_col0" class="data row0 col0" >0.8285</td>
#                         <td id="T_4f1e0_row0_col1" class="data row0 col1" >0.7105</td>
#                         <td id="T_4f1e0_row0_col2" class="data row0 col2" >0.9776</td>
#                         <td id="T_4f1e0_row0_col3" class="data row0 col3" >0.8380</td>
#                         <td id="T_4f1e0_row0_col4" class="data row0 col4" >0.9024</td>
#                         <td id="T_4f1e0_row0_col5" class="data row0 col5" >0.2273</td>
#                         <td id="T_4f1e0_row0_col6" class="data row0 col6" >0.2865</td>
#                         <td id="T_4f1e0_row0_col7" class="data row0 col7" >0.8374</td>
#             </tr>
#             <tr>
#                         <th id="T_4f1e0_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4f1e0_row1_col0" class="data row1 col0" >0.8304</td>
#                         <td id="T_4f1e0_row1_col1" class="data row1 col1" >0.7188</td>
#                         <td id="T_4f1e0_row1_col2" class="data row1 col2" >0.9778</td>
#                         <td id="T_4f1e0_row1_col3" class="data row1 col3" >0.8396</td>
#                         <td id="T_4f1e0_row1_col4" class="data row1 col4" >0.9034</td>
#                         <td id="T_4f1e0_row1_col5" class="data row1 col5" >0.2390</td>
#                         <td id="T_4f1e0_row1_col6" class="data row1 col6" >0.2986</td>
#                         <td id="T_4f1e0_row1_col7" class="data row1 col7" >0.8389</td>
#             </tr>
#             <tr>
#                         <th id="T_4f1e0_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4f1e0_row2_col0" class="data row2 col0" >0.8293</td>
#                         <td id="T_4f1e0_row2_col1" class="data row2 col1" >0.7142</td>
#                         <td id="T_4f1e0_row2_col2" class="data row2 col2" >0.9781</td>
#                         <td id="T_4f1e0_row2_col3" class="data row2 col3" >0.8384</td>
#                         <td id="T_4f1e0_row2_col4" class="data row2 col4" >0.9029</td>
#                         <td id="T_4f1e0_row2_col5" class="data row2 col5" >0.2306</td>
#                         <td id="T_4f1e0_row2_col6" class="data row2 col6" >0.2908</td>
#                         <td id="T_4f1e0_row2_col7" class="data row2 col7" >0.8378</td>
#             </tr>
#             <tr>
#                         <th id="T_4f1e0_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4f1e0_row3_col0" class="data row3 col0" >0.8302</td>
#                         <td id="T_4f1e0_row3_col1" class="data row3 col1" >0.7131</td>
#                         <td id="T_4f1e0_row3_col2" class="data row3 col2" >0.9782</td>
#                         <td id="T_4f1e0_row3_col3" class="data row3 col3" >0.8391</td>
#                         <td id="T_4f1e0_row3_col4" class="data row3 col4" >0.9034</td>
#                         <td id="T_4f1e0_row3_col5" class="data row3 col5" >0.2363</td>
#                         <td id="T_4f1e0_row3_col6" class="data row3 col6" >0.2968</td>
#                         <td id="T_4f1e0_row3_col7" class="data row3 col7" >0.8385</td>
#             </tr>
#             <tr>
#                         <th id="T_4f1e0_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4f1e0_row4_col0" class="data row4 col0" >0.8306</td>
#                         <td id="T_4f1e0_row4_col1" class="data row4 col1" >0.7176</td>
#                         <td id="T_4f1e0_row4_col2" class="data row4 col2" >0.9790</td>
#                         <td id="T_4f1e0_row4_col3" class="data row4 col3" >0.8391</td>
#                         <td id="T_4f1e0_row4_col4" class="data row4 col4" >0.9036</td>
#                         <td id="T_4f1e0_row4_col5" class="data row4 col5" >0.2364</td>
#                         <td id="T_4f1e0_row4_col6" class="data row4 col6" >0.2983</td>
#                         <td id="T_4f1e0_row4_col7" class="data row4 col7" >0.8385</td>
#             </tr>
#             <tr>
#                         <th id="T_4f1e0_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4f1e0_row5_col0" class="data row5 col0" >0.8293</td>
#                         <td id="T_4f1e0_row5_col1" class="data row5 col1" >0.7128</td>
#                         <td id="T_4f1e0_row5_col2" class="data row5 col2" >0.9776</td>
#                         <td id="T_4f1e0_row5_col3" class="data row5 col3" >0.8387</td>
#                         <td id="T_4f1e0_row5_col4" class="data row5 col4" >0.9029</td>
#                         <td id="T_4f1e0_row5_col5" class="data row5 col5" >0.2326</td>
#                         <td id="T_4f1e0_row5_col6" class="data row5 col6" >0.2919</td>
#                         <td id="T_4f1e0_row5_col7" class="data row5 col7" >0.8381</td>
#             </tr>
#             <tr>
#                         <th id="T_4f1e0_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_4f1e0_row6_col0" class="data row6 col0" >0.8290</td>
#                         <td id="T_4f1e0_row6_col1" class="data row6 col1" >0.7115</td>
#                         <td id="T_4f1e0_row6_col2" class="data row6 col2" >0.9776</td>
#                         <td id="T_4f1e0_row6_col3" class="data row6 col3" >0.8384</td>
#                         <td id="T_4f1e0_row6_col4" class="data row6 col4" >0.9027</td>
#                         <td id="T_4f1e0_row6_col5" class="data row6 col5" >0.2304</td>
#                         <td id="T_4f1e0_row6_col6" class="data row6 col6" >0.2897</td>
#                         <td id="T_4f1e0_row6_col7" class="data row6 col7" >0.8378</td>
#             </tr>
#             <tr>
#                         <th id="T_4f1e0_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_4f1e0_row7_col0" class="data row7 col0" >0.8289</td>
#                         <td id="T_4f1e0_row7_col1" class="data row7 col1" >0.7146</td>
#                         <td id="T_4f1e0_row7_col2" class="data row7 col2" >0.9777</td>
#                         <td id="T_4f1e0_row7_col3" class="data row7 col3" >0.8383</td>
#                         <td id="T_4f1e0_row7_col4" class="data row7 col4" >0.9026</td>
#                         <td id="T_4f1e0_row7_col5" class="data row7 col5" >0.2295</td>
#                         <td id="T_4f1e0_row7_col6" class="data row7 col6" >0.2890</td>
#                         <td id="T_4f1e0_row7_col7" class="data row7 col7" >0.8377</td>
#             </tr>
#             <tr>
#                         <th id="T_4f1e0_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_4f1e0_row8_col0" class="data row8 col0" >0.8288</td>
#                         <td id="T_4f1e0_row8_col1" class="data row8 col1" >0.7145</td>

# %%
preds_lightgbm = predict_model(tuned_lightgbm, data = X_test, raw_score=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_fbca9_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >PR AUC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fbca9_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_fbca9_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_fbca9_row0_col1" class="data row0 col1" >0.9529</td>
#                         <td id="T_fbca9_row0_col2" class="data row0 col2" >0.7158</td>
#                         <td id="T_fbca9_row0_col3" class="data row0 col3" >0.9778</td>
#                         <td id="T_fbca9_row0_col4" class="data row0 col4" >0.9737</td>
#                         <td id="T_fbca9_row0_col5" class="data row0 col5" >0.9757</td>
#                         <td id="T_fbca9_row0_col6" class="data row0 col6" >0.1816</td>
#                         <td id="T_fbca9_row0_col7" class="data row0 col7" >0.1820</td>
#                         <td id="T_fbca9_row0_col8" class="data row0 col8" >0.9736</td>
#             </tr>
#     </tbody></table>

# %%
final_model = finalize_model(tuned_lightgbm)
save_model(final_model, 'predict_tip')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=False, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='tip',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strateg...
#                                  colsample_bytree=1.0, feature_fraction=0.7,
#                                  importance_type='split', learning_rate=0.3,
#                                  max_depth=-1, min_child_samples=56,
#                                  min_child_weight=0.001, min_split_gain=0.4,
#                                  n_estimators=110, n_jobs=-1, num_leaves=256,
#                                  objective=None, random_state=6830, reg_alpha=2,
#                                  reg_lambda=0.15, silent='warn', subsample=1.0,
#                                  subsample_for_bin=200000, subsample_freq=0)]],
#           verbose=False),
#  'predict_tip.pkl')

# %%
xgboost_model = create_model('xgboost',fold=10)
tuned_xgboost = tune_model(xgboost_model, optimize = 'prauc',fold=10)
# Out:
# <style  type="text/css" >
# #T_9e8e7_row10_col0,#T_9e8e7_row10_col1,#T_9e8e7_row10_col2,#T_9e8e7_row10_col3,#T_9e8e7_row10_col4,#T_9e8e7_row10_col5,#T_9e8e7_row10_col6,#T_9e8e7_row10_col7{
#             background:  yellow;
#         }</style><table id="T_9e8e7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>        <th class="col_heading level0 col7" >PR AUC</th>    </tr>    <tr>        <th class="index_name level0" >Fold</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9e8e7_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9e8e7_row0_col0" class="data row0 col0" >0.8152</td>
#                         <td id="T_9e8e7_row0_col1" class="data row0 col1" >0.6926</td>
#                         <td id="T_9e8e7_row0_col2" class="data row0 col2" >0.9982</td>
#                         <td id="T_9e8e7_row0_col3" class="data row0 col3" >0.8154</td>
#                         <td id="T_9e8e7_row0_col4" class="data row0 col4" >0.8976</td>
#                         <td id="T_9e8e7_row0_col5" class="data row0 col5" >0.0417</td>
#                         <td id="T_9e8e7_row0_col6" class="data row0 col6" >0.1253</td>
#                         <td id="T_9e8e7_row0_col7" class="data row0 col7" >0.8154</td>
#             </tr>
#             <tr>
#                         <th id="T_9e8e7_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9e8e7_row1_col0" class="data row1 col0" >0.8158</td>
#                         <td id="T_9e8e7_row1_col1" class="data row1 col1" >0.6949</td>
#                         <td id="T_9e8e7_row1_col2" class="data row1 col2" >0.9982</td>
#                         <td id="T_9e8e7_row1_col3" class="data row1 col3" >0.8159</td>
#                         <td id="T_9e8e7_row1_col4" class="data row1 col4" >0.8979</td>
#                         <td id="T_9e8e7_row1_col5" class="data row1 col5" >0.0470</td>
#                         <td id="T_9e8e7_row1_col6" class="data row1 col6" >0.1355</td>
#                         <td id="T_9e8e7_row1_col7" class="data row1 col7" >0.8159</td>
#             </tr>
#             <tr>
#                         <th id="T_9e8e7_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9e8e7_row2_col0" class="data row2 col0" >0.8146</td>
#                         <td id="T_9e8e7_row2_col1" class="data row2 col1" >0.6975</td>
#                         <td id="T_9e8e7_row2_col2" class="data row2 col2" >0.9986</td>
#                         <td id="T_9e8e7_row2_col3" class="data row2 col3" >0.8147</td>
#                         <td id="T_9e8e7_row2_col4" class="data row2 col4" >0.8973</td>
#                         <td id="T_9e8e7_row2_col5" class="data row2 col5" >0.0346</td>
#                         <td id="T_9e8e7_row2_col6" class="data row2 col6" >0.1150</td>
#                         <td id="T_9e8e7_row2_col7" class="data row2 col7" >0.8147</td>
#             </tr>
#             <tr>
#                         <th id="T_9e8e7_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_9e8e7_row3_col0" class="data row3 col0" >0.8156</td>
#                         <td id="T_9e8e7_row3_col1" class="data row3 col1" >0.6956</td>
#                         <td id="T_9e8e7_row3_col2" class="data row3 col2" >0.9982</td>
#                         <td id="T_9e8e7_row3_col3" class="data row3 col3" >0.8157</td>
#                         <td id="T_9e8e7_row3_col4" class="data row3 col4" >0.8978</td>
#                         <td id="T_9e8e7_row3_col5" class="data row3 col5" >0.0447</td>
#                         <td id="T_9e8e7_row3_col6" class="data row3 col6" >0.1315</td>
#                         <td id="T_9e8e7_row3_col7" class="data row3 col7" >0.8157</td>
#             </tr>
#             <tr>
#                         <th id="T_9e8e7_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_9e8e7_row4_col0" class="data row4 col0" >0.8159</td>
#                         <td id="T_9e8e7_row4_col1" class="data row4 col1" >0.6966</td>
#                         <td id="T_9e8e7_row4_col2" class="data row4 col2" >0.9980</td>
#                         <td id="T_9e8e7_row4_col3" class="data row4 col3" >0.8161</td>
#                         <td id="T_9e8e7_row4_col4" class="data row4 col4" >0.8979</td>
#                         <td id="T_9e8e7_row4_col5" class="data row4 col5" >0.0484</td>
#                         <td id="T_9e8e7_row4_col6" class="data row4 col6" >0.1367</td>
#                         <td id="T_9e8e7_row4_col7" class="data row4 col7" >0.8161</td>
#             </tr>
#             <tr>
#                         <th id="T_9e8e7_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_9e8e7_row5_col0" class="data row5 col0" >0.8161</td>
#                         <td id="T_9e8e7_row5_col1" class="data row5 col1" >0.6923</td>
#                         <td id="T_9e8e7_row5_col2" class="data row5 col2" >0.9982</td>
#                         <td id="T_9e8e7_row5_col3" class="data row5 col3" >0.8161</td>
#                         <td id="T_9e8e7_row5_col4" class="data row5 col4" >0.8980</td>
#                         <td id="T_9e8e7_row5_col5" class="data row5 col5" >0.0491</td>
#                         <td id="T_9e8e7_row5_col6" class="data row5 col6" >0.1392</td>
#                         <td id="T_9e8e7_row5_col7" class="data row5 col7" >0.8161</td>
#             </tr>
#             <tr>
#                         <th id="T_9e8e7_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_9e8e7_row6_col0" class="data row6 col0" >0.8154</td>
#                         <td id="T_9e8e7_row6_col1" class="data row6 col1" >0.6929</td>
#                         <td id="T_9e8e7_row6_col2" class="data row6 col2" >0.9986</td>
#                         <td id="T_9e8e7_row6_col3" class="data row6 col3" >0.8154</td>
#                         <td id="T_9e8e7_row6_col4" class="data row6 col4" >0.8977</td>
#                         <td id="T_9e8e7_row6_col5" class="data row6 col5" >0.0416</td>
#                         <td id="T_9e8e7_row6_col6" class="data row6 col6" >0.1288</td>
#                         <td id="T_9e8e7_row6_col7" class="data row6 col7" >0.8154</td>
#             </tr>
#             <tr>
#                         <th id="T_9e8e7_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_9e8e7_row7_col0" class="data row7 col0" >0.8152</td>
#                         <td id="T_9e8e7_row7_col1" class="data row7 col1" >0.6959</td>
#                         <td id="T_9e8e7_row7_col2" class="data row7 col2" >0.9981</td>
#                         <td id="T_9e8e7_row7_col3" class="data row7 col3" >0.8155</td>
#                         <td id="T_9e8e7_row7_col4" class="data row7 col4" >0.8976</td>
#                         <td id="T_9e8e7_row7_col5" class="data row7 col5" >0.0423</td>
#                         <td id="T_9e8e7_row7_col6" class="data row7 col6" >0.1260</td>
#                         <td id="T_9e8e7_row7_col7" class="data row7 col7" >0.8155</td>
#             </tr>
#             <tr>
#                         <th id="T_9e8e7_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_9e8e7_row8_col0" class="data row8 col0" >0.8149</td>
#                         <td id="T_9e8e7_row8_col1" class="data row8 col1" >0.6986</td>

# %%
preds_xgboost = predict_model(tuned_xgboost, data = X_test, raw_score=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_23900_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >PR AUC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_23900_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_23900_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#                         <td id="T_23900_row0_col1" class="data row0 col1" >0.9677</td>
#                         <td id="T_23900_row0_col2" class="data row0 col2" >0.6985</td>
#                         <td id="T_23900_row0_col3" class="data row0 col3" >0.9986</td>
#                         <td id="T_23900_row0_col4" class="data row0 col4" >0.9690</td>
#                         <td id="T_23900_row0_col5" class="data row0 col5" >0.9836</td>
#                         <td id="T_23900_row0_col6" class="data row0 col6" >0.0427</td>
#                         <td id="T_23900_row0_col7" class="data row0 col7" >0.0885</td>
#                         <td id="T_23900_row0_col8" class="data row0 col8" >0.9690</td>
#             </tr>
#     </tbody></table>
# /Users/ocabrerarose/opt/anaconda3/envs/fiuba/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/ocabrerarose/opt/anaconda3/envs/fiuba/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/ocabrerarose/opt/anaconda3/envs/fiuba/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/ocabrerarose/opt/anaconda3/envs/fiuba/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/ocabrerarose/opt/anaconda3/envs/fiuba/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/ocabrerarose/opt/anaconda3/envs/fiuba/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/ocabrerarose/opt/anaconda3/envs/fiuba/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)

# %%
tuned_xgboost
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.3, max_delta_step=0, max_depth=10,
#               min_child_weight=4, missing=nan, monotone_constraints='()',
#               n_estimators=220, n_jobs=-1, num_parallel_tree=1,
#               objective='binary:logistic', random_state=6830, reg_alpha=0.01,
#               reg_lambda=0.4, scale_pos_weight=37.4, subsample=0.2,
#               tree_method='auto', use_label_encoder=True, validate_parameters=1,
#               verbosity=0)

# %%
final_model_xgboost = finalize_model(tuned_xgboost)
save_model(final_model_xgboost, 'predict_tip_xgboost')

# %%
saved_model = load_model('predict_tip_xgboost')

# %%
X_test_sample = X_test.sample(100000).reset_index(drop=True)

# %%
X_test_sample_pipe = saved_model[:-1].transform(X_test_sample)

# %%
explainer = shap.TreeExplainer(saved_model.named_steps["trained_model"])
shap_values = explainer.shap_values(X_test_sample_pipe)

# %%
idx = 0
shap.force_plot(explainer.expected_value, shap_values[idx,:], X_test_sample_pipe.iloc[idx,:])
